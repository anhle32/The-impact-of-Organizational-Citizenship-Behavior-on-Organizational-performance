# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('df.csv')

# %%
df.head()
# Out:
#    CO1  CO2  CO3  CO4  AL1  AL2  AL3  AL4  AL5  CN1  ...  CV4  TLS1  TLS2  \
# 0    3    4    4    4    2    2    3    3    2    3  ...    4     3     4
# 1    3    3    3    3    3    3    4    4    3    4  ...    2     4     4
# 2    3    3    4    4    3    4    4    3    5    4  ...    2     4     5
# 3    2    2    2    3    2    3    3    2    3    3  ...    2     2     2
# 4    2    3    3    2    1    2    2    3    2    3  ...    3     3     3
#
#    TLS3  TLS4  TLS5  OP1  OP2  OP3  OP4
# 0     2     3     4    3    3    3    3
# 1     5     4     4    5    5    4    4
# 2     5     4     5    4    4    4    3
# 3     2     2     2    3    2    2    3
# 4     3     3     3    2    1    2    3
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#      CO1  CO2  CO3  CO4  AL1  AL2  AL3  AL4  AL5  CN1  ...  CV4  TLS1  TLS2  \
# 479    2    3    2    3    3    3    4    4    4    3  ...    2     2     3
# 480    3    2    2    2    3    3    3    3    3    4  ...    4     3     3
# 481    3    3    4    2    2    2    3    3    3    3  ...    4     3     3
# 482    3    3    3    2    3    3    4    4    4    4  ...    4     3     3
# 483    5    5    4    5    3    4    4    4    4    4  ...    4     4     5
#
#      TLS3  TLS4  TLS5  OP1  OP2  OP3  OP4
# 479     2     2     2    2    2    3    3
# 480     3     3     3    4    3    4    4
# 481     4     4     4    3    3    3    3
# 482     3     3     3    3    2    3    4
# 483     4     4     4    4    4    4    4
#
# [5 rows x 30 columns]

# %%
df1=df[['CO1','CO2','CO3','CO4','AL1','AL2','AL3','AL4','AL5','CN1','CN2','CN3','CN4','SP1','SP2','SP3','SP4','CV1','CV2','CV3','CV4']]

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="variable", y="value", data=pd.melt(df1))
plt.show()

# %%
df2=df[['TLS1','TLS2','TLS3','TLS4','TLS5']]

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="variable", y="value", data=pd.melt(df2))
plt.show()

# %%
df3=df[['OP1','OP2','OP3','OP4']]

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="variable", y="value", data=pd.melt(df3))
plt.show()

# %%
Q1_H = df.CO2.quantile(0.25)
Q3_H = df.CO2.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.CO2 < H_lower_bound].index)
df = df.drop(df[df.CO2 > H_upper_bound].index)

# %%
df.shape
# Out:
# (478, 30)

# %%
Q1_H = df.CO4.quantile(0.25)
Q3_H = df.CO4.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.CO4 < H_lower_bound].index)
df = df.drop(df[df.CO4 > H_upper_bound].index)

# %%
df.shape
# Out:
# (475, 30)

# %%
Q1_H = df.CN1.quantile(0.25)
Q3_H = df.CN1.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.CN1 < H_lower_bound].index)
df = df.drop(df[df.CN1 > H_upper_bound].index)

# %%
df.shape
# Out:
# (469, 30)

# %%
Q1_H = df.CN2.quantile(0.25)
Q3_H = df.CN2.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.CN2 < H_lower_bound].index)
df = df.drop(df[df.CN2 > H_upper_bound].index)

# %%
df.shape
# Out:
# (466, 30)

# %%
Q1_H = df.CN3.quantile(0.25)
Q3_H = df.CN3.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.CN3 < H_lower_bound].index)
df = df.drop(df[df.CN3 > H_upper_bound].index)

# %%
df.shape
# Out:
# (463, 30)

# %%
Q1_H = df.CV1.quantile(0.25)
Q3_H = df.CV1.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.CV1 < H_lower_bound].index)
df = df.drop(df[df.CV1 > H_upper_bound].index)

# %%
df.shape
# Out:
# (460, 30)

# %%
Q1_H = df.CV3.quantile(0.25)
Q3_H = df.CV3.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.CV3 < H_lower_bound].index)
df = df.drop(df[df.CV3 > H_upper_bound].index)

# %%
df.shape
# Out:
# (460, 30)

# %%
Q1_H = df.CV4.quantile(0.25)
Q3_H = df.CV4.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.CV4 < H_lower_bound].index)
df = df.drop(df[df.CV4 > H_upper_bound].index)

# %%
df.shape
# Out:
# (460, 30)

# %%
Q1_H = df.TLS1.quantile(0.25)
Q3_H = df.TLS1.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.TLS1 < H_lower_bound].index)
df = df.drop(df[df.TLS1 > H_upper_bound].index)

# %%
df.shape
# Out:
# (454, 30)

# %%
Q1_H = df.TLS2.quantile(0.25)
Q3_H = df.TLS2.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.TLS2 < H_lower_bound].index)
df = df.drop(df[df.TLS2 > H_upper_bound].index)
df.shape
# Out:
# (451, 30)

# %%
Q1_H = df.TLS3.quantile(0.25)
Q3_H = df.TLS3.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.TLS3 < H_lower_bound].index)
df = df.drop(df[df.TLS3 > H_upper_bound].index)
df.shape
# Out:
# (451, 30)

# %%
Q1_H = df.TLS4.quantile(0.25)
Q3_H = df.TLS4.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.TLS4 < H_lower_bound].index)
df = df.drop(df[df.TLS4 > H_upper_bound].index)
df.shape
# Out:
# (451, 30)

# %%
Q1_H = df.TLS5.quantile(0.25)
Q3_H = df.TLS5.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.TLS5 < H_lower_bound].index)
df = df.drop(df[df.TLS5 > H_upper_bound].index)
df.shape
# Out:
# (451, 30)

# %%
Q1_H = df.OP1.quantile(0.25)
Q3_H = df.OP1.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.OP1 < H_lower_bound].index)
df = df.drop(df[df.OP1 > H_upper_bound].index)
df.shape
# Out:
# (448, 30)

# %%
Q1_H = df.OP2.quantile(0.25)
Q3_H = df.OP2.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.OP2 < H_lower_bound].index)
df = df.drop(df[df.OP2 > H_upper_bound].index)
df.shape
# Out:
# (445, 30)

# %%
Q1_H = df.OP3.quantile(0.25)
Q3_H = df.OP3.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.OP3 < H_lower_bound].index)
df = df.drop(df[df.OP3 > H_upper_bound].index)
df.shape
# Out:
# (442, 30)

# %%
Q1_H = df.OP4.quantile(0.25)
Q3_H = df.OP4.quantile(0.75)
IQR_H = Q3_H - Q1_H
H_lower_bound = Q1_H - (1.5 * IQR_H) 
H_upper_bound = Q3_H + (1.5 * IQR_H) 
df = df.drop(df[df.OP4 < H_lower_bound].index)
df = df.drop(df[df.OP4 > H_upper_bound].index)
df.shape
# Out:
# (439, 30)

# %%
df.to_csv('data1.csv')

# %%
plt.figure(figsize=(24,10))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>
